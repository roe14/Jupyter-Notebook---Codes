# %%
# -*- coding: utf-8 -*-
"""

@author: Roelof
"""



import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

#Create Dictionary of different lists
data={"Countries":["India","USA","EL Salvador","United Kingdom","Colombia"],
      "2000":[4.56,5.53,60.31,1.55,66.97],"2001":[4.32,6.64,60.57,1.63,69.16],
      "2002":[4.18,5.65,47.55,1.87,69.45],"2003":[3.99,5.70,55.99,1.55,56.70],
      "2004":[4.12,5.52,64.69,1.59,48.03],"2005":[3.93,5.67,64.14,1.38,42.47],
      "2006":[3.86,5.81,64.60,1.41,40.46],"2007":[3.83,5.70,57.27,1.42,39.32],
      "2008":[3.83,5.43,51.84,1.23,36.47],"2009":[3.76,5.03,71.76,1.12,35.35],
      "2010":[3.76,4.76,64.47,1.19,34.18],"2011":[3.81,4.71,70.38,1.00,35.32],
      "2012":[3.75,4.73,41.58,0.97,35.68],"2013":[3.58,4.53,40.10,0.93,33.16],
      "2014":[3.66,4.44,62.69,0.90,28.41],"2015":[3.39,4.95,105.23,0.99,26.90],
      "2016":[3.22,5.39,83.01,1.19,25.74],"2017":[3.12,5.32,61.71,1.20,25.02],
      "2018":[3.08,4.96,52.02,1.20,25.39]}
#Convert to a data frame using .from_dict()
df=pd.DataFrame.from_dict(data)

                                    #Edit the Data Frame
                                    
#Get the Average for each row, axi=1 pertains to row where 0 pertains to columns                                 
average=df.mean(axis=1)
#Add new column and add the average values/Cant use only integer as name
Year_2019=[3.77,5.28,62.10,1.28,40.74]
df["Year_2019"]=Year_2019
#Rename the column to 2019
df.rename(columns={"Year_2019":"2019"},inplace=True)
#Calculate the annual percentage change/dataframe.pct_change()


                                    #Create the Area Plot
                                    
#Set the country name as the index - usefull for quickly looking up country using loc method
df.set_index("Countries",inplace=True)
#Transpose the dataframe
years=list(map(str,range(2000,2020)))
df=df[years].transpose()

#Style Sheets for the plot
mpl.style.use(["fivethirtyeight"])
print(plt.style.available)

#Plot the Area Plot
df.plot(kind="area",stacked="False",figsize=(10,5))
plt.title("Homocide Rate per 100,000 ppl")
plt.xlabel("Years",fontsize=12)
plt.ylabel("Homocide Rate",fontsize=12)
plt.legend(fontsize=8)
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
